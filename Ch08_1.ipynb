# %%
from google.colab.patches import cv2_imshow
from google.colab import drive
import numpy as np # numpy는 배열 사용할 때
import cv2
import matplotlib.pyplot as plt
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
img = cv2.imread('/content/gdrive/My Drive/ImageProcessing/Ch01/IP/Images/char.bmp')
print(img.shape)
gImg1 = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
cv2_imshow(gImg1)
# Out:
# (256, 256, 3)
# <PIL.Image.Image image mode=L size=256x256>

# %%
kernel = np.ones((3,3), np.uint8)
dilateImg = cv2.dilate(gImg1, kernel, iterations = 1)
cv2_imshow(dilateImg)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
edgeImg = dilateImg - gImg1
cv2_imshow(edgeImg)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
kernel = np.ones((5,5), np.uint8)
dilateImg = cv2.dilate(gImg1, kernel, iterations = 1)
cv2_imshow(dilateImg)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
edgeImg = dilateImg - gImg1
cv2_imshow(edgeImg)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
kernel = np.ones((7,7), np.uint8)
dilateImg = cv2.dilate(gImg1, kernel, iterations = 1)
cv2_imshow(dilateImg)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
img = cv2.imread('/content/gdrive/My Drive/ImageProcessing/Ch01/IP/Images/milkdrop.bmp')
print(img.shape)
gImg2 = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
cv2_imshow(gImg2)
# Out:
# (256, 256, 3)
# <PIL.Image.Image image mode=L size=256x256>

# %%
kernel = np.ones((3,3), np.uint8)
dilateImg = cv2.dilate(gImg2, kernel, iterations = 1)
cv2_imshow(dilateImg)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
gBin = np.zeros((gImg2.shape[0], gImg2.shape[1]), dtype = np.uint8)

threshold = 128
for i in range(gImg2.shape[0]):
  for j in range(gImg2.shape[1]):
    if gImg2[i, j] > threshold:
      gBin[i, j] = 255

cv2_imshow(gBin)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
gBin = np.zeros((gImg2.shape[0], gImg2.shape[1]), dtype = np.uint8)

threshold = 150
for i in range(gImg2.shape[0]):
  for j in range(gImg2.shape[1]):
    if gImg2[i, j] > threshold:
      gBin[i, j] = 255

cv2_imshow(gBin)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
kernel = np.ones((3,3), np.uint8)
dilateImg = cv2.dilate(gBin, kernel, iterations = 4)
cv2_imshow(dilateImg)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (3,3))
dilateImg = cv2.dilate(gBin, kernel, iterations = 3)
cv2_imshow(dilateImg)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (3,3))
dilateImg = cv2.dilate(gBin, kernel, iterations = 3)
cv2_imshow(dilateImg)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
kernel = cv2.getStructuringElement(cv2.MORPH_CROSS, (3,3))
dilateImg = cv2.dilate(gBin, kernel, iterations = 3)
cv2_imshow(dilateImg)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
kernel = np.ones((1,3), np.uint8)
dilateImg = cv2.dilate(gBin, kernel, iterations = 3)
cv2_imshow(dilateImg)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
kernel = np.ones((3,1), np.uint8)
dilateImg = cv2.dilate(gBin, kernel, iterations = 3)
cv2_imshow(dilateImg)
# Out:
# <PIL.Image.Image image mode=L size=256x256>
