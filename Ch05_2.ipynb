# %%
from google.colab.patches import cv2_imshow
from google.colab import drive
import numpy as np # numpy는 배열 사용할 때
import cv2
import matplotlib.pyplot as plt
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
img = cv2.imread('/content/gdrive/My Drive/Ch01/IP/Images/고소영3.jpg')
print(img.shape)
gImg1 = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
cv2_imshow(gImg1)
# Out:
# (275, 183, 3)
# <PIL.Image.Image image mode=L size=183x275>

# %%
outImg = cv2.blur(gImg1, (5, 5))
cv2_imshow(outImg)
# Out:
# <PIL.Image.Image image mode=L size=183x275>

# %%
outImg = cv2.GaussianBlur(gImg1, (7, 7), 5)
cv2_imshow(outImg)
# Out:
# <PIL.Image.Image image mode=L size=183x275>

# %%
outImg = cv2.medianBlur(gImg1, 7)
cv2_imshow(outImg)
# Out:
# <PIL.Image.Image image mode=L size=183x275>

# %%
outImage = gImg1.copy()
blurImage = cv2.GaussianBlur(outImage, (7, 7), 5)

x = 100 - 20
y = 100 - 25
size = 10

for h in range(y, y+size):
  for w in range(x, x+size):
    outImage[h][w] = 255

cv2_imshow(outImage)
# Out:
# <PIL.Image.Image image mode=L size=183x275>

# %%
outImage = gImg1.copy()
blurImage = cv2.medianBlur(outImage, 7, 5)

x = 100 - 25
y = 100 - 25
size = 10

for h in range(y, y+size):
  for w in range(x, x+size):
    outImage[h][w] = 255

cv2_imshow(outImage)
# Out:
# <PIL.Image.Image image mode=L size=183x275>

# %%
img = cv2.imread('/content/gdrive/My Drive/Ch01/IP/Images/lena256.jpg')
print(img.shape)
gImg2 = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
cv2_imshow(gImg2)
# Out:
# (256, 256, 3)
# <PIL.Image.Image image mode=L size=256x256>

# %%
outImg = cv2.GaussianBlur(gImg2, (7, 7), 1)
cv2_imshow(outImg)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
edgeImage = cv2.addWeighted(gImg2, 1, outImg, -1, 0)
cv2_imshow(edgeImage)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
unsharpImage = cv2.addWeighted(gImg2, 1, edgeImage, 1, 0)
cv2_imshow(unsharpImage)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
kernel3 = np.ones((3,3), np.float32) / 9
kernel3[0][0] = -1/9
kernel3[0][1] = -1/9
kernel3[0][2] = -1/9
kernel3[1][0] = -1/9
kernel3[1][1] = 8/9
kernel3[1][2] = -1/9
kernel3[2][0] = -1/9
kernel3[2][1] = -1/9
kernel3[2][2] = -1/9

# %%
outImg = cv2.filter2D(gImg2, -1, kernel3)
cv2_imshow(outImg)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
kernel3 = np.ones((3,3), np.float32) / 9
kernel3[0][0] = -1/9
kernel3[0][1] = -1/9
kernel3[0][2] = -1/9
kernel3[1][0] = -1/9
kernel3[1][1] = 17/9
kernel3[1][2] = -1/9
kernel3[2][0] = -1/9
kernel3[2][1] = -1/9
kernel3[2][2] = -1/9

# %%
outImg = cv2.filter2D(gImg2, -1, kernel3)
cv2_imshow(outImg)
# Out:
# <PIL.Image.Image image mode=L size=256x256>
